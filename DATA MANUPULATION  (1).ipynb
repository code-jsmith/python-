# %%
#panda
#import neccessary libraries
import numpy as np #numerical python
import pandas as pd#creating tabular data dataframe
import matplotlib.pyplot as plt#visualisation
import seaborn as sns#visualization
import warnings
warnings.filterwarnings("ignore")#warnings will be imporved

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\Titanic Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#inspecting dataset
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
#lower rows
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
#no of rows and column
df.shape
# Out:
# (891, 12)

# %%
#only rows
len(df)
# Out:
# 891

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 12

# %%
#columns with datatype and non null value
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#descriptive statistics
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#code to detect null value
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop("Cabin",axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Embarked'],
#       dtype='object')

# %%
#percentage wisenull values
df.isnull().sum()/len(df)*100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Embarked        0.224467
# dtype: float64

# %%
# in order to utilize age and embarked since they have very low values of null count
#we will just drop the missing values in row and not the entire column
df.dropna(inplace=True)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#two methods of indexing .loc and .iloc method

# %%
#.loc
df.loc[:,'Age'] #0 to 890 is an indexing
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 712, dtype: float64

# %%
df.loc[0:5,('Survived','Age','Sex')]
# Out:
#    Survived   Age     Sex
# 0         0  22.0    male
# 1         1  38.0  female
# 2         1  26.0  female
# 3         1  35.0  female
# 4         0  35.0    male

# %%
df.loc[885:889,('Survived','Age','Sex')]
# Out:
#      Survived   Age     Sex
# 885         0  39.0  female
# 886         0  27.0    male
# 887         1  19.0  female
# 889         1  26.0    male

# %%
df.loc[len(df)-5:len(df),('Survived','Age','Sex')]
# Out:
#      Survived   Age     Sex
# 707         1  42.0    male
# 708         1  22.0  female
# 710         1  24.0  female
# 712         1  48.0    male

# %%
df[df['Sex']== 'male']#when you want to filter based on column value
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Embarked
# ...

# %%
#dataset filter embarked cloumn where it is s
df[df["Embarked"]=="S"]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# ..           ...       ...     ...
# 882          883         0       3
# 883          884         0       2
# 884          885         0       3
# 886          887         0       2
# 887          888         1       1
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                         Braund, Mr. Owen Harris    male  22.0      1      0
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# ...

# %%
#combining filter
df[(df["Sex"]=='female') & (df["Age"]> 25)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 866          867         1       2
# 871          872         1       1
# 874          875         1       2
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# male,survived1,,embarked
df[(df["Survived"]==1) & (df["Sex"]=="male") & (df["Embarked"]=="C")]
# Out:
#      PassengerId  Survived  Pclass  \
# 97            98         1       1
# 125          126         1       3
# 207          208         1       3
# 209          210         1       1
# 370          371         1       1
# 453          454         1       1
# 455          456         1       3
# 484          485         1       1
# 550          551         1       1
# 553          554         1       3
# 587          588         1       1
# 599          600         1       1
# 604          605         1       1
# 622          623         1       3
# 632          633         1       1
# 645          646         1       1
# 647          648         1       1
# 679          680         1       1
# 681          682         1       1
# 737          738         1       1
# 762          763         1       3
# 803          804         1       3
# 827          828         1       2
# 889          890         1       1
#
# ...

# %%
#male ya female age >40 embarked s ya c and survived = 1
df[(df["Survived"]==1) & ((df["Sex"]=="male")|(df["Sex"]=="female")) & ((df["Embarked"]=="C")|(df["Embarked"]=="S"))& (df["Age"]>40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 11            12         1       1
# 15            16         1       2
# 52            53         1       1
# 187          188         1       1
# 194          195         1       1
# 195          196         1       1
# 259          260         1       2
# 268          269         1       1
# 272          273         1       2
# 275          276         1       1
# 288          289         1       2
# 299          300         1       1
# 337          338         1       1
# 338          339         1       3
# 366          367         1       1
# 380          381         1       1
# 414          415         1       3
# 432          433         1       2
# 440          441         1       2
# 449          450         1       1
# 453          454         1       1
# 458          459         1       2
# 460          461         1       1
# 483          484         1       3
# 496          497         1       1
# ...

# %%
df.iloc[:,3:6]
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [712 rows x 3 columns]

# %%
#expolatory data analysis

# %%
#visualisation
#a-->  uni-variate analysis
#b--> bi-variate analysis
#c--> multi -variate analysis

# %%
#histogram to do univeriate analysis
sns.histplot(data = df,x='Age',y=None)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data = df,x='Fare',y=None)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
#Pair plot
sns.pairplot(df)

# %%
#barchart
sns.barplot(data=df,x='Sex',y='PassengerId',hue="Pclass")
# Out:
# <Axes: xlabel='Sex', ylabel='PassengerId'>

# %%
#CORRELATION MATRIX---> numerical values
df1 = df.select_dtypes(exclude ="object")

# %%
df1.info
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 885          886         0       3  39.0      0      5  29.1250
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [712 rows x 7 columns]>

# %%
df1.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000  0.029526 -0.035609  0.033681 -0.082704 -0.011672
# Survived        0.029526  1.000000 -0.356462 -0.082446 -0.015523  0.095265
# Pclass         -0.035609 -0.356462  1.000000 -0.365902  0.065187  0.023666
# Age             0.033681 -0.082446 -0.365902  1.000000 -0.307351 -0.187896
# SibSp          -0.082704 -0.015523  0.065187 -0.307351  1.000000  0.383338
# Parch          -0.011672  0.095265  0.023666 -0.187896  0.383338  1.000000
# Fare            0.009655  0.266100 -0.552893  0.093143  0.139860  0.206624
#
#                  Fare
# PassengerId  0.009655
# Survived     0.266100
# Pclass      -0.552893
# Age          0.093143
# SibSp        0.139860
# Parch        0.206624
# Fare         1.000000

# %%
sns.heatmap(df1.corr(),annot=True)
# Out:
# <Axes: >

# %%
#merging
#concat
#pivot table
#grouping
#sorting

# %%
df1=df

# %%
df1 #first dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df#second dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.merge?
# Out:
# Signature:
# pd.merge(
#     left: 'DataFrame | Series',
#     right: 'DataFrame | Series',
#     how: 'MergeHow' = 'inner',
#     on: 'IndexLabel | AnyArrayLike | None' = None,
#     left_on: 'IndexLabel | AnyArrayLike | None' = None,
#     right_on: 'IndexLabel | AnyArrayLike | None' = None,
#     left_index: 'bool' = False,
#     right_index: 'bool' = False,
#     sort: 'bool' = False,
#     suffixes: 'Suffixes' = ('_x', '_y'),
#     copy: 'bool | None' = None,
#     indicator: 'str | bool' = False,
#     validate: 'str | None' = None,
# ) -> 'DataFrame'
# Docstring:
# Merge DataFrame or named Series objects with a database-style join.
#
# A named Series object is treated as a DataFrame with a single named column.
#
# The join is done on columns or indexes. If joining columns on
# columns, the DataFrame indexes *will be ignored*. Otherwise if joining indexes
# on indexes or indexes on a column or columns, the index will be passed on.
# ...

# %%
pd.merge(left=df1,right=df,how ="inner",on="PassengerId")
# Out:
#      PassengerId  Survived_x  Pclass_x  \
# 0              1           0         3
# 1              2           1         1
# 2              3           1         3
# 3              4           1         1
# 4              5           0         3
# ..           ...         ...       ...
# 707          886           0         3
# 708          887           0         2
# 709          888           1         1
# 710          890           1         1
# 711          891           0         3
#
#                                                 Name_x   Sex_x  Age_x  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ...

# %%
pd.concat([df1,df],axis=0)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby(['Pclass']).size()
# Out:
# Pclass
# 1    184
# 2    173
# 3    355
# dtype: int64

# %%
df.groupby(['Pclass']).mean('Fare')
# Out:
#         PassengerId  Survived        Age     SibSp     Parch       Fare
# Pclass
# 1        464.157609  0.652174  38.105543  0.456522  0.413043  88.048121
# 2        447.156069  0.479769  29.877630  0.427746  0.404624  21.471556
# 3        441.219718  0.239437  25.140620  0.585915  0.456338  13.229435

# %%
df.groupby('Pclass')['Fare'].count()
# Out:
# Pclass
# 1    184
# 2    173
# 3    355
# Name: Fare, dtype: int64

# %%
df.groupby(['Pclass','sex'])
[['Fare']].mean().sort_values(by='Fare',ascending = false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.groupby(['Pclass','sex'])
#       2 [['Fare']].mean().sort_values(by='Fare',ascending = false)
#
# NameError: name 'df' is not defined

# %%
df.groupby(['Embarked','Survived'])[['Fare']].mean().sort_values(by='Fare',ascending=False)
# Out:
#                         Fare
# Embarked Survived
# C        1         85.641935
#          0         41.428761
# S        1         39.599875
#          0         20.573050
# Q        1         18.655212
#          0         18.110000

# %%
#sorting
df.sort_values(by="Age",ascending=False)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
# 96            97         0       1             Goldschmidt, Mr. George B
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 116          117         0       3                  Connors, Mr. Patrick
# ..           ...       ...     ...                                   ...
# 831          832         1       2       Richards, Master. George Sibley
# 469          470         1       3         Baclini, Miss. Helene Barbara
# 644          645         1       3                Baclini, Miss. Eugenie
# 755          756         1       2             Hamalainen, Master. Viljo
# 803          804         1       3       Thomas, Master. Assad Alexander
#
#         Sex    Age  SibSp  Parch    Ticket     Fare Embarked
# ...

# %%
df[['Age']].sort_values(by="Age",ascending=False)
# Out:
#        Age
# 630  80.00
# 851  74.00
# 96   71.00
# 493  71.00
# 116  70.50
# ..     ...
# 831   0.83
# 469   0.75
# 644   0.75
# 755   0.67
# 803   0.42
#
# [712 rows x 1 columns]

# %%
#select two column aggregate by a third numerical coloumn and then sort descending by
df.groupby(['PassengerId','Survived'])[['Fare']].mean().sort_values(by='PassengerId',ascending=False)
# Out:
#                          Fare
# PassengerId Survived
# 891         0          7.7500
# 890         1         30.0000
# 888         1         30.0000
# 887         0         13.0000
# 886         0         29.1250
# ...                       ...
# 5           0          8.0500
# 4           1         53.1000
# 3           1          7.9250
# 2           1         71.2833
# 1           0          7.2500
#
# [712 rows x 1 columns]

# %%
df.groupby(['Sex','Pclass']).agg({"Fare":"sum","Age":"mean"})
# Out:
#                     Fare        Age
# Sex    Pclass
# female 1       9015.4334  34.240964
#        2       1624.3792  28.722973
#        3       1619.2876  21.750000
# male   1       7185.4209  41.281386
#        2       2090.2000  30.740707
#        3       3077.1619  26.507589

# %%
def num(a):
    return a**2

# %%
num(23)
# Out:
# 529
